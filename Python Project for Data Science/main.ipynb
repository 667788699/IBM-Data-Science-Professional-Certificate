# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install --upgrade plotly
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = "iframe"
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)
def make_graph(stock_data, revenue_data, stock):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
    fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data_specific.Date, infer_datetime_format=True), y=stock_data_specific.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data_specific.Date, infer_datetime_format=True), y=revenue_data_specific.Revenue.astype("float"), name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=1)
    fig.update_layout(showlegend=False,
    height=900,
    title=stock,
    xaxis_rangeslider_visible=True)
    fig.show()
    from IPython.display import display, HTML
    fig_html = fig.to_html()
    display(HTML(fig_html))
# Out:
# Requirement already satisfied: yfinance in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (0.2.65)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.10.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.25.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: requests>=2.31 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: pycparser in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: bs4 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from bs4) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4) (4.14.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nbformat in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (5.10.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (0.24.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (310)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.14.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (6.3.0)
# Requirement already satisfied: packaging in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages (from plotly) (2.2.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\實驗室電腦\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Q1

# %%
tsla = yf.Ticker("TSLA")
tesla_data = tsla.history(period="max")
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
# Failed to get ticker 'TSLA' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\Users\實驗室電腦\AppData\Local\Programs\Python\Python310\lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# $TSLA: possibly delisted; no timezone found
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []
